# %%
# Question 1

import numpy as np

arr = np.random.rand(10,1)
print(arr)
print("Mean: ",np.mean(arr))
# Out:
# [[0.5816192 ]
#  [0.75393806]
#  [0.28808065]
#  [0.48456286]
#  [0.69247143]
#  [0.73844063]
#  [0.91260682]
#  [0.75841208]
#  [0.76982908]
#  [0.10337289]]
# Mean:  0.6083333699141743

# %%
# Question 2

import numpy as np

arr = np.random.rand(20,1)
print(arr)
print("Variance: ",np.var(arr))
print("Standard Deviation: ",np.std(arr))
# Out:
# [[6.19202975e-01]
#  [6.51590939e-01]
#  [3.09927259e-01]
#  [9.59152431e-01]
#  [8.71307894e-01]
#  [5.13489897e-01]
#  [2.18760964e-01]
#  [7.36046652e-01]
#  [4.71589131e-01]
#  [8.23290627e-01]
#  [4.06360342e-01]
#  [8.44331039e-01]
#  [8.98690186e-01]
#  [6.35106984e-04]
#  [2.49862338e-01]
#  [9.43960534e-01]
#  [6.58729682e-01]
#  [5.62046219e-02]
#  [1.38671551e-01]
#  [9.06184970e-01]]
# Variance:  0.09468395245614361
# Standard Deviation:  0.3077075762085549

# %%
# Question 3

import numpy as np

A = np.random.rand(10,20)
B = np.random.rand(20,25)

arrMul = np.matmul(A,B)
print(arrMul)
print("Shape of new matrix: ",np.shape(arrMul))
print("Sum of all elements: ",np.sum(arrMul))
# Out:
# [[5.43987553 4.98798412 4.78427069 6.1133208  4.75218617 5.5853248
#   4.96474945 5.05474287 5.4785431  5.25416899 4.34755566 3.84272159
#   4.24890554 4.41364604 3.9661497  3.59130503 5.58069719 4.98034578
#   3.33770156 4.4009369  6.66618764 5.44374275 5.35052459 5.43047408
#   5.40439693]
#  [5.75869112 5.00891915 4.97804649 6.44913731 5.50446814 5.51537023
#   5.18957015 5.1808118  6.2091916  6.2253883  4.36439532 4.27008642
#   5.00047075 5.70641553 5.17965027 3.96688159 6.39799987 5.53328149
#   3.76283395 5.29953466 7.77444281 6.05805375 5.84654724 6.34114107
#   6.21224187]
#  [5.23208629 5.23469467 5.70299537 6.22930992 5.46706045 5.16545254
#   5.1430126  6.08806653 6.3112186  5.52232417 4.9768598  4.87861149
#   4.54329392 4.73203569 5.38865486 3.62898638 5.76806832 4.60456558
#   4.64634503 5.61878167 6.79985801 5.45353811 6.35711231 5.10520029
#   7.10635201]
#  [4.69302389 4.75391034 5.49409448 5.52612612 4.73879406 4.54154403
# ...

# %%
# Question 4

import numpy as np

Arr =np.random.rand(10,1)

print("Random Array: ",Arr)

print('*'*40)

def fxn(x):
    return (1 / (1 + np.exp(-x)))

NewArr = np.apply_along_axis(fxn,0,Arr)

print("New Array :",NewArr)
# Out:
# Random Array:  [[0.47405832]
#  [0.38655636]
#  [0.59319432]
#  [0.24149987]
#  [0.3731087 ]
#  [0.68309964]
#  [0.90316814]
#  [0.7540571 ]
#  [0.28805155]
#  [0.04916817]]
# ****************************************
# New Array : [[0.61634385]
#  [0.59545344]
#  [0.64409774]
#  [0.56008323]
#  [0.59220994]
#  [0.66443015]
#  [0.71160012]
#  [0.68006208]
#  [0.57151905]
#  [0.51228957]]
